# %%
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import pandas_datareader as pdr


import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
from xgboost import XGBRegressor

# %% [markdown]
# ## Data Visualization

# %%
def get_data(ticker):
    data = pdr.get_data_yahoo(ticker, start="2000-01-01").iloc[:-1][['Close']]
    data[f"{ticker}_return"] = np.log(data.Close) - np.log(data.Close).shift(1)
    data = data.dropna()
    data = data[[f"{ticker}_return"]]
    return data

# %%
ihsg = get_data('^JKSE').rename(columns = {'^JKSE_return':'IHSG'})
dow_jones = get_data('^DJI').rename(columns = {'^DJI_return':'dow_jones'})
SnP500 = get_data('^GSPC').rename(columns = {'^GSPC_return':'SnP500'})
nasdaq = get_data('^IXIC').rename(columns = {'^IXIC_return':'nasdaq'})
russell = get_data('^RUT').rename(columns = {'^RUT_return':'russell'})
dax = get_data('^GDAXI').rename(columns={'^GDAXI_return':'DAX'})
nikkei = get_data('^N225').rename(columns={'^N225_return':'nikkei'})
hang_seng = get_data('^HSI').rename(columns={'^HSI_return':'hangseng'})
nifty = get_data('^NSEI').rename(columns={'^NSEI_return':'Nifty50'})

# %%
df = ihsg.join(dow_jones).join(SnP500).join(nasdaq).join(russell).join(dax).join(nikkei).join(hang_seng).join(nifty)

# %%
df = df.dropna()

# %%
df.to_csv('data_saved/full_data.csv')

# %%
df.head()
# Out:
#                 IHSG  dow_jones    SnP500    nasdaq   russell       DAX  \
# Date
# 2007-09-18  0.007457   0.024757  0.028790  0.026753  0.038957  0.012668
# 2007-09-19  0.032278   0.005529  0.006068  0.005573  0.013264  0.022920
# 2007-09-20 -0.003771  -0.003543 -0.006746 -0.004582 -0.009391 -0.002034
# 2007-09-21  0.013300   0.003878  0.004598  0.006358  0.004128  0.007642
# 2007-09-25 -0.009935   0.001423 -0.000343  0.005793 -0.003481 -0.002376
#
#               nikkei  hangseng   Nifty50
# Date
# 2007-09-18 -0.020397 -0.000915  0.011404
# 2007-09-19  0.036031  0.039014  0.040130
# 2007-09-20  0.001967  0.005716  0.003207
# 2007-09-21 -0.006183  0.005535  0.018780
# 2007-09-25  0.005448 -0.004592  0.001347

# %%
fig, ax = plt.subplots(figsize=(10,5))

sns.heatmap(data=df.corr(), cmap='crest', annot=True)
ax.set_title('Correlation between Indexes Returns')

fig.savefig('pic/correlation.png')

# %% [markdown]
# ## Split data

# %%
train = df.loc[df.index < '2018-01-01']
test = df.loc[df.index >= '2018-01-01']

# %%
X_train = train.drop(columns="IHSG")
y_train = train[['IHSG']]

# %%
X_test = test.drop(columns='IHSG')
y_test = test[['IHSG']]

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.plot(y_train, label="train_data", color="blue")
ax.plot(y_test, label="test_data", color="red")
ax.legend()
ax.set_title("IHSG Return Train and Test Data")

fig.savefig('pic/ihsg_return_train_test.png')

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### XGB Regressor

# %%
model = XGBRegressor(n_estimators=500)

# %%
model.fit(X_train, 
          y_train, 
          eval_set = [(X_train, y_train), (X_test, y_test)]
         )
# Out:
# [0]	validation_0-rmse:0.35011	validation_1-rmse:0.35033
# [1]	validation_0-rmse:0.24531	validation_1-rmse:0.24550
# [2]	validation_0-rmse:0.17202	validation_1-rmse:0.17215
# [3]	validation_0-rmse:0.12078	validation_1-rmse:0.12076
# [4]	validation_0-rmse:0.08497	validation_1-rmse:0.08494
# [5]	validation_0-rmse:0.06001	validation_1-rmse:0.06003
# [6]	validation_0-rmse:0.04267	validation_1-rmse:0.04283
# [7]	validation_0-rmse:0.03070	validation_1-rmse:0.03095
# [8]	validation_0-rmse:0.02255	validation_1-rmse:0.02293
# [9]	validation_0-rmse:0.01706	validation_1-rmse:0.01779
# [10]	validation_0-rmse:0.01354	validation_1-rmse:0.01460
# [11]	validation_0-rmse:0.01127	validation_1-rmse:0.01279
# [12]	validation_0-rmse:0.00990	validation_1-rmse:0.01178
# [13]	validation_0-rmse:0.00910	validation_1-rmse:0.01119
# [14]	validation_0-rmse:0.00855	validation_1-rmse:0.01092
# [15]	validation_0-rmse:0.00817	validation_1-rmse:0.01083
# [16]	validation_0-rmse:0.00794	validation_1-rmse:0.01078
# [17]	validation_0-rmse:0.00776	validation_1-rmse:0.01075
# [18]	validation_0-rmse:0.00764	validation_1-rmse:0.01072
# [19]	validation_0-rmse:0.00756	validation_1-rmse:0.01071
# [20]	validation_0-rmse:0.00750	validation_1-rmse:0.01074
# [21]	validation_0-rmse:0.00735	validation_1-rmse:0.01075
# [22]	validation_0-rmse:0.00726	validation_1-rmse:0.01076
# [23]	validation_0-rmse:0.00710	validation_1-rmse:0.01080
# [24]	validation_0-rmse:0.00700	validation_1-rmse:0.01081
# [25]	validation_0-rmse:0.00692	validation_1-rmse:0.01081
# [26]	validation_0-rmse:0.00685	validation_1-rmse:0.01082
# [27]	validation_0-rmse:0.00680	validation_1-rmse:0.01083
# [28]	validation_0-rmse:0.00664	validation_1-rmse:0.01087
# [29]	validation_0-rmse:0.00651	validation_1-rmse:0.01089
# [30]	validation_0-rmse:0.00646	validation_1-rmse:0.01091
# [31]	validation_0-rmse:0.00639	validation_1-rmse:0.01091
# [32]	validation_0-rmse:0.00622	validation_1-rmse:0.01090
# [33]	validation_0-rmse:0.00605	validation_1-rmse:0.01091
# [34]	validation_0-rmse:0.00600	validation_1-rmse:0.01093
# [35]	validation_0-rmse:0.00588	validation_1-rmse:0.01095
# [36]	validation_0-rmse:0.00568	validation_1-rmse:0.01097
# [37]	validation_0-rmse:0.00555	validation_1-rmse:0.01095
# [38]	validation_0-rmse:0.00546	validation_1-rmse:0.01100
# [39]	validation_0-rmse:0.00534	validation_1-rmse:0.01103
# [40]	validation_0-rmse:0.00529	validation_1-rmse:0.01103
# [41]	validation_0-rmse:0.00524	validation_1-rmse:0.01103
# [42]	validation_0-rmse:0.00513	validation_1-rmse:0.01103
# [43]	validation_0-rmse:0.00511	validation_1-rmse:0.01104
# [44]	validation_0-rmse:0.00500	validation_1-rmse:0.01108
# [45]	validation_0-rmse:0.00497	validation_1-rmse:0.01106
# [46]	validation_0-rmse:0.00492	validation_1-rmse:0.01109
# [47]	validation_0-rmse:0.00484	validation_1-rmse:0.01109
# [48]	validation_0-rmse:0.00478	validation_1-rmse:0.01108
# [49]	validation_0-rmse:0.00469	validation_1-rmse:0.01110
# [50]	validation_0-rmse:0.00462	validation_1-rmse:0.01111
# [51]	validation_0-rmse:0.00456	validation_1-rmse:0.01111
# [52]	validation_0-rmse:0.00449	validation_1-rmse:0.01111
# [53]	validation_0-rmse:0.00443	validation_1-rmse:0.01113
# [54]	validation_0-rmse:0.00438	validation_1-rmse:0.01113
# [55]	validation_0-rmse:0.00425	validation_1-rmse:0.01114
# [56]	validation_0-rmse:0.00417	validation_1-rmse:0.01114
# [57]	validation_0-rmse:0.00411	validation_1-rmse:0.01116
# [58]	validation_0-rmse:0.00407	validation_1-rmse:0.01116
# [59]	validation_0-rmse:0.00402	validation_1-rmse:0.01118
# [60]	validation_0-rmse:0.00399	validation_1-rmse:0.01118
# [61]	validation_0-rmse:0.00391	validation_1-rmse:0.01120
# [62]	validation_0-rmse:0.00389	validation_1-rmse:0.01120
# [63]	validation_0-rmse:0.00383	validation_1-rmse:0.01120
# [64]	validation_0-rmse:0.00378	validation_1-rmse:0.01121
# [65]	validation_0-rmse:0.00375	validation_1-rmse:0.01121
# [66]	validation_0-rmse:0.00369	validation_1-rmse:0.01120
# [67]	validation_0-rmse:0.00365	validation_1-rmse:0.01121
# [68]	validation_0-rmse:0.00362	validation_1-rmse:0.01122
# [69]	validation_0-rmse:0.00358	validation_1-rmse:0.01121
# [70]	validation_0-rmse:0.00354	validation_1-rmse:0.01121
# [71]	validation_0-rmse:0.00348	validation_1-rmse:0.01122
# [72]	validation_0-rmse:0.00342	validation_1-rmse:0.01123
# [73]	validation_0-rmse:0.00337	validation_1-rmse:0.01123
# [74]	validation_0-rmse:0.00335	validation_1-rmse:0.01124
# [75]	validation_0-rmse:0.00330	validation_1-rmse:0.01124
# [76]	validation_0-rmse:0.00326	validation_1-rmse:0.01125
# [77]	validation_0-rmse:0.00324	validation_1-rmse:0.01126
# [78]	validation_0-rmse:0.00322	validation_1-rmse:0.01126
# [79]	validation_0-rmse:0.00317	validation_1-rmse:0.01127
# [80]	validation_0-rmse:0.00311	validation_1-rmse:0.01128
# [81]	validation_0-rmse:0.00307	validation_1-rmse:0.01129
# [82]	validation_0-rmse:0.00303	validation_1-rmse:0.01129
# [83]	validation_0-rmse:0.00302	validation_1-rmse:0.01128
# [84]	validation_0-rmse:0.00298	validation_1-rmse:0.01129
# [85]	validation_0-rmse:0.00293	validation_1-rmse:0.01131
# [86]	validation_0-rmse:0.00288	validation_1-rmse:0.01131
# [87]	validation_0-rmse:0.00285	validation_1-rmse:0.01131
# [88]	validation_0-rmse:0.00280	validation_1-rmse:0.01131
# [89]	validation_0-rmse:0.00274	validation_1-rmse:0.01133
# [90]	validation_0-rmse:0.00272	validation_1-rmse:0.01133
# [91]	validation_0-rmse:0.00269	validation_1-rmse:0.01133
# [92]	validation_0-rmse:0.00266	validation_1-rmse:0.01133
# [93]	validation_0-rmse:0.00265	validation_1-rmse:0.01134
# [94]	validation_0-rmse:0.00260	validation_1-rmse:0.01134
# [95]	validation_0-rmse:0.00254	validation_1-rmse:0.01135
# [96]	validation_0-rmse:0.00250	validation_1-rmse:0.01134
# [97]	validation_0-rmse:0.00247	validation_1-rmse:0.01134
# [98]	validation_0-rmse:0.00244	validation_1-rmse:0.01133
# [99]	validation_0-rmse:0.00243	validation_1-rmse:0.01134
# [100]	validation_0-rmse:0.00240	validation_1-rmse:0.01134
# [101]	validation_0-rmse:0.00236	validation_1-rmse:0.01135
# [102]	validation_0-rmse:0.00231	validation_1-rmse:0.01135
# [103]	validation_0-rmse:0.00228	validation_1-rmse:0.01136
# [104]	validation_0-rmse:0.00226	validation_1-rmse:0.01136
# [105]	validation_0-rmse:0.00224	validation_1-rmse:0.01136
# [106]	validation_0-rmse:0.00223	validation_1-rmse:0.01136
# [107]	validation_0-rmse:0.00220	validation_1-rmse:0.01136
# [108]	validation_0-rmse:0.00217	validation_1-rmse:0.01136
# [109]	validation_0-rmse:0.00216	validation_1-rmse:0.01136
# [110]	validation_0-rmse:0.00215	validation_1-rmse:0.01136
# [111]	validation_0-rmse:0.00211	validation_1-rmse:0.01136
# [112]	validation_0-rmse:0.00208	validation_1-rmse:0.01136
# [113]	validation_0-rmse:0.00204	validation_1-rmse:0.01136
# [114]	validation_0-rmse:0.00201	validation_1-rmse:0.01136
# [115]	validation_0-rmse:0.00199	validation_1-rmse:0.01136
# [116]	validation_0-rmse:0.00197	validation_1-rmse:0.01137
# [117]	validation_0-rmse:0.00194	validation_1-rmse:0.01137
# [118]	validation_0-rmse:0.00192	validation_1-rmse:0.01137
# [119]	validation_0-rmse:0.00190	validation_1-rmse:0.01138
# [120]	validation_0-rmse:0.00189	validation_1-rmse:0.01138
# [121]	validation_0-rmse:0.00186	validation_1-rmse:0.01138
# [122]	validation_0-rmse:0.00185	validation_1-rmse:0.01138
# [123]	validation_0-rmse:0.00179	validation_1-rmse:0.01139
# [124]	validation_0-rmse:0.00177	validation_1-rmse:0.01139
# [125]	validation_0-rmse:0.00173	validation_1-rmse:0.01139
# [126]	validation_0-rmse:0.00171	validation_1-rmse:0.01139
# [127]	validation_0-rmse:0.00170	validation_1-rmse:0.01139
# [128]	validation_0-rmse:0.00168	validation_1-rmse:0.01139
# [129]	validation_0-rmse:0.00165	validation_1-rmse:0.01139
# [130]	validation_0-rmse:0.00163	validation_1-rmse:0.01140
# [131]	validation_0-rmse:0.00161	validation_1-rmse:0.01140
# [132]	validation_0-rmse:0.00159	validation_1-rmse:0.01140
# [133]	validation_0-rmse:0.00157	validation_1-rmse:0.01140
# [134]	validation_0-rmse:0.00154	validation_1-rmse:0.01141
# [135]	validation_0-rmse:0.00152	validation_1-rmse:0.01140
# [136]	validation_0-rmse:0.00148	validation_1-rmse:0.01140
# [137]	validation_0-rmse:0.00146	validation_1-rmse:0.01140
# [138]	validation_0-rmse:0.00145	validation_1-rmse:0.01141
# [139]	validation_0-rmse:0.00144	validation_1-rmse:0.01140
# [140]	validation_0-rmse:0.00143	validation_1-rmse:0.01141
# [141]	validation_0-rmse:0.00140	validation_1-rmse:0.01141
# [142]	validation_0-rmse:0.00139	validation_1-rmse:0.01141
# [143]	validation_0-rmse:0.00136	validation_1-rmse:0.01141
# [144]	validation_0-rmse:0.00135	validation_1-rmse:0.01141
# [145]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [146]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [147]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [148]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [149]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [150]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [151]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [152]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [153]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [154]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [155]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [156]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [157]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [158]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [159]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [160]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [161]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [162]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [163]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [164]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [165]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [166]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [167]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [168]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [169]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [170]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [171]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [172]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [173]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [174]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [175]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [176]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [177]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [178]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [179]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [180]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [181]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [182]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [183]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [184]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [185]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [186]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [187]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [188]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [189]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [190]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [191]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [192]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [193]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [194]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [195]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [196]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [197]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [198]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [199]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [200]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [201]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [202]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [203]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [204]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [205]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [206]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [207]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [208]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [209]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [210]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [211]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [212]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [213]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [214]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [215]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [216]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [217]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [218]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [219]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [220]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [221]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [222]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [223]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [224]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [225]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [226]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [227]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [228]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [229]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [230]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [231]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [232]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [233]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [234]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [235]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [236]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [237]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [238]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [239]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [240]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [241]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [242]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [243]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [244]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [245]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [246]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [247]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [248]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [249]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [250]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [251]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [252]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [253]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [254]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [255]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [256]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [257]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [258]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [259]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [260]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [261]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [262]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [263]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [264]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [265]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [266]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [267]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [268]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [269]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [270]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [271]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [272]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [273]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [274]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [275]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [276]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [277]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [278]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [279]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [280]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [281]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [282]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [283]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [284]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [285]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [286]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [287]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [288]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [289]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [290]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [291]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [292]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [293]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [294]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [295]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [296]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [297]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [298]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [299]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [300]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [301]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [302]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [303]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [304]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [305]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [306]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [307]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [308]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [309]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [310]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [311]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [312]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [313]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [314]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [315]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [316]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [317]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [318]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [319]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [320]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [321]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [322]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [323]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [324]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [325]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [326]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [327]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [328]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [329]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [330]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [331]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [332]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [333]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [334]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [335]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [336]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [337]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [338]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [339]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [340]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [341]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [342]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [343]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [344]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [345]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [346]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [347]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [348]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [349]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [350]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [351]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [352]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [353]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [354]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [355]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [356]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [357]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [358]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [359]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [360]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [361]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [362]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [363]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [364]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [365]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [366]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [367]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [368]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [369]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [370]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [371]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [372]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [373]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [374]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [375]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [376]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [377]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [378]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [379]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [380]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [381]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [382]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [383]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [384]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [385]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [386]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [387]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [388]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [389]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [390]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [391]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [392]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [393]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [394]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [395]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [396]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [397]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [398]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [399]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [400]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [401]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [402]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [403]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [404]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [405]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [406]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [407]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [408]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [409]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [410]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [411]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [412]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [413]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [414]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [415]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [416]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [417]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [418]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [419]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [420]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [421]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [422]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [423]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [424]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [425]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [426]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [427]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [428]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [429]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [430]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [431]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [432]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [433]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [434]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [435]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [436]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [437]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [438]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [439]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [440]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [441]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [442]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [443]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [444]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [445]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [446]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [447]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [448]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [449]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [450]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [451]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [452]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [453]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [454]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [455]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [456]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [457]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [458]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [459]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [460]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [461]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [462]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [463]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [464]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [465]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [466]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [467]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [468]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [469]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [470]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [471]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [472]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [473]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [474]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [475]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [476]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [477]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [478]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [479]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [480]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [481]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [482]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [483]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [484]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [485]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [486]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [487]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [488]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [489]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [490]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [491]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [492]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [493]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [494]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [495]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [496]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [497]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [498]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# [499]	validation_0-rmse:0.00135	validation_1-rmse:0.01142
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=500, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %% [markdown]
# ## Feature Importance

# %%
fi = pd.DataFrame(data=model.feature_importances_, 
              index=model.feature_names_in_, 
              columns=['importance'])

# %%
fi.sort_values('importance').plot(kind='barh', 
                                  title='Feature Importance', 
                                  figsize=(10, 5))

plt.savefig('pic/feature_importance.png')

# %% [markdown]
# ## Forecast

# %%
test['prediction'] = model.predict(X_test)
# Out:
# C:\Users\fitra\AppData\Local\Temp\ipykernel_8156\3864373789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['prediction'] = model.predict(X_test)

# %%
df = df.merge(test[['prediction']], how="left", left_index=True, right_index=True)

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.plot(df[['IHSG']], label = "IHSG Returns")
df['prediction'].plot(label="preds")

plt.legend()
plt.title("IHSG Return Prediction")

plt.savefig('pic/prediction.png')

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.plot(test[['IHSG']][test.index>'2022-10-01'], label="IHSG Returns")
df['prediction'][df.index>'2022-10-01'].plot(label="preds")

plt.legend()
plt.title("IHSG Return Prediction Zoom in")

fig.savefig('pic/prediction_zoom_in.png')
